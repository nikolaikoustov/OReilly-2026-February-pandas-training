# %% [markdown]
# Overview
# --------
# This notebook is used to load and analyze customer.csv

# %%
import pumpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
s = Series([1, 2, 3, 4, 5])
s
